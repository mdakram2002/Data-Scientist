# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['Akku', 'Atiya', 'Peter', 'Linda'],
    'Age': [22, 18, 34, 45],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [50000, 20000, 30000, 40000],
}
pd.DataFrame(data)
# Out:
#     Name  Age      City  Salary
# 0   Akku   22  New York   50000
# 1  Atiya   18     Paris   20000
# 2  Peter   34    Berlin   30000
# 3  Linda   45    London   40000

# %%
data_list = [
    ['Akku', 22, 'New York', 50000],
    ['Atiya', 18, 'Paris', 20000],
    ['Peter', 22, 'Berlin', 30000],
    ['Linda', 22, 'London', 40000]
]
df = pd.DataFrame(data_list)


columns = ['Name', 'Age', 'City', 'Salary']
df = pd.DataFrame(data_list, columns = columns)
df
# Out:
#     Name  Age      City  Salary
# 0   Akku   22  New York   50000
# 1  Atiya   18     Paris   20000
# 2  Peter   22    Berlin   30000
# 3  Linda   22    London   40000

# %%
df['Name']
# Out:
# 0     Akku
# 1    Atiya
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0   Akku   22
# 1  Atiya   18
# 2  Peter   22
# 3  Linda   22

# %%
df['Designation'] = ['Eng', 'Doctor', 'Doctor', 'Eng']

# %%
df
# Out:
#     Name  Age      City  Salary Degignation Designation
# 0   Akku   22  New York   50000         Eng         Eng
# 1  Atiya   18     Paris   20000      Doctor      Doctor
# 2  Peter   22    Berlin   30000      Doctor      Doctor
# 3  Linda   22    London   40000         Eng         Eng

# %%
df.drop(['Designation', 'City'], axis = 1) # Axis 1 for Vertical
# Out:
#     Name  Age  Salary
# 0   Akku   22   50000
# 1  Atiya   18   20000
# 2  Peter   22   30000
# 3  Linda   22   40000

# %%
df.drop(2, axis = 0) # Axis 0 for horizontal
# Out:
#     Name  Age      City  Salary Designation
# 0   Akku   22  New York   50000         Eng
# 1  Atiya   18     Paris   20000      Doctor
# 3  Linda   22    London   40000         Eng

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   Akku   22  New York   50000         Eng
# 1  Atiya   18     Paris   20000      Doctor
# 2  Peter   22    Berlin   30000      Doctor
# 3  Linda   22    London   40000         Eng

# %%
df.loc[0]
# Out:
# Name               Akku
# Age                  22
# City           New York
# Salary            50000
# Designation         Eng
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#     Name  Age      City  Salary Designation
# 0   Akku   22  New York   50000         Eng
# 1  Atiya   18     Paris   20000      Doctor

# %%
df.loc[3]
# Out:
# Name            Linda
# Age                22
# City           London
# Salary          40000
# Designation       Eng
# Name: 3, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#     Name  Age      City  Salary Designation
# 0   Akku   22  New York   50000         Eng
# 1  Atiya   18     Paris   20000      Doctor

# %%
df.loc[[0, 1]][['City', 'Salary']]
# Out:
#        City  Salary
# 0  New York   50000
# 1     Paris   20000

# %%
df.loc[[2, 3]]
# Out:
#     Name  Age    City  Salary Designation
# 2  Peter   22  Berlin   30000      Doctor
# 3  Linda   22  London   40000         Eng

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   22
# 3  Linda   22

# %%
# Condinal Selection

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   Akku   22  New York   50000         Eng
# 1  Atiya   18     Paris   20000      Doctor
# 2  Peter   22    Berlin   30000      Doctor
# 3  Linda   22    London   40000         Eng

# %%
# I only want to see those whose age is 20+
df[df['Age'] > 20]
# Out:
#     Name  Age      City  Salary Designation
# 0   Akku   22  New York   50000         Eng
# 2  Peter   22    Berlin   30000      Doctor
# 3  Linda   22    London   40000         Eng

# %%
# I only want whose age is above 20 and city from new york
df[(df['Age'] > 20) & (df['City'] == 'New York')]
# Out:
#    Name  Age      City  Salary Designation
# 0  Akku   22  New York   50000         Eng
