# %%
import numpy as np
import pandas as pd

# %%
labels = ['s', 'b', 'c']
my_list = [10, 20, 30]
arr = np.array([10, 20, 30])
my_disc = {1: 10, 2: 20, 3: 30}

# %%
pd.Series(my_list, index = labels)
# Out:
# s    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# s    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(my_disc)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
